# %%
# %%capture
# !pip install hyperas
# !pip install hyperopt

# %% [markdown]
# # Import dataset from Google Drive

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# pietro
output_preprocessing = pd.read_csv("/content/drive/My Drive/UnimiB/Magistrale/Secondo Anno/Advanced Machine Learning/Progetto AML/output_preprocessing_50_clusters.csv")
# carlo
#output_preprocessing = pd.read_csv("/content/drive/My Drive/universita/magistrale/advanced_machine_learning/Progetto AML/output_preprocessing_50_clusters.csv")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
output_preprocessing.head()
# Out:
#    total_distance  total_travel_time  ...  pickup_minute  pickup_day_week
# 0          2009.1              164.9  ...             24                0
# 1          2513.2              332.0  ...             43                6
# 2          1779.4              235.8  ...             32                2
# 3          1614.9              140.1  ...             30                5
# 4          1393.5              189.4  ...              1                5
#
# [5 rows x 22 columns]

# %% [markdown]
# # Keras train test definition

# %%
import numpy as np
from sklearn.model_selection import train_test_split

cols = list(output_preprocessing.columns.values)
cols.remove('trip_duration')

target = output_preprocessing.loc[:, 'trip_duration']
features = output_preprocessing.loc[:, cols]

train_features, test_features, train_target, test_target = \
    train_test_split(features, target, test_size=0.20, random_state=0)

train_x, train_y = np.array(train_features), np.array(train_target)
test_x, test_y = np.array(test_features), np.array(test_target)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_scaled_x = scaler.fit_transform(train_x)
test_scaled_x = scaler.transform(test_x)

# %% [markdown]
# # Model

# %%
from keras.layers.core import Dense, Dropout, Activation
from keras.models import Sequential
from keras.utils import np_utils

num_features = train_scaled_x.shape[1]

model = Sequential()
model.add(Dense(128, input_dim=num_features, activation='relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1, activation = 'relu'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse', 'mae', 'mape', 'cosine'])
model.summary()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 9,121
# Trainable params: 9,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Testing the model

# %%
history = model.fit(train_scaled_x, np.log(train_y + 1), epochs=100, 
          batch_size=256, validation_split=0.2, verbose=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 925585 samples, validate on 231397 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 925585/925585 [==============================] - 10s 11us/step - loss: 0.3911 - mean_squared_error: 0.3911 - mean_absolute_error: 0.3643 - mean_absolute_percentage_error: 5.7964 - cosine_proximity: -1.0000 - val_loss: 0.1498 - val_mean_squared_error: 0.1498 - val_mean_absolute_error: 0.2908 - val_mean_absolute_percentage_error: 4.6867 - val_cosine_proximity: -1.0000
# Epoch 2/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1462 - mean_squared_error: 0.1462 - mean_absolute_error: 0.2854 - mean_absolute_percentage_error: 4.5572 - cosine_proximity: -1.0000 - val_loss: 0.1481 - val_mean_squared_error: 0.1481 - val_mean_absolute_error: 0.2891 - val_mean_absolute_percentage_error: 4.6828 - val_cosine_proximity: -1.0000
# Epoch 3/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1429 - mean_squared_error: 0.1429 - mean_absolute_error: 0.2815 - mean_absolute_percentage_error: 4.4961 - cosine_proximity: -1.0000 - val_loss: 0.1394 - val_mean_squared_error: 0.1394 - val_mean_absolute_error: 0.2762 - val_mean_absolute_percentage_error: 4.4032 - val_cosine_proximity: -1.0000
# Epoch 4/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1408 - mean_squared_error: 0.1408 - mean_absolute_error: 0.2789 - mean_absolute_percentage_error: 4.4552 - cosine_proximity: -1.0000 - val_loss: 0.1439 - val_mean_squared_error: 0.1439 - val_mean_absolute_error: 0.2809 - val_mean_absolute_percentage_error: 4.4299 - val_cosine_proximity: -1.0000
# Epoch 5/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1391 - mean_squared_error: 0.1391 - mean_absolute_error: 0.2770 - mean_absolute_percentage_error: 4.4239 - cosine_proximity: -1.0000 - val_loss: 0.1361 - val_mean_squared_error: 0.1361 - val_mean_absolute_error: 0.2729 - val_mean_absolute_percentage_error: 4.3603 - val_cosine_proximity: -1.0000
# Epoch 6/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1376 - mean_squared_error: 0.1376 - mean_absolute_error: 0.2752 - mean_absolute_percentage_error: 4.3954 - cosine_proximity: -1.0000 - val_loss: 0.1443 - val_mean_squared_error: 0.1443 - val_mean_absolute_error: 0.2843 - val_mean_absolute_percentage_error: 4.6153 - val_cosine_proximity: -1.0000
# Epoch 7/100
# 925585/925585 [==============================] - 10s 10us/step - loss: 0.1368 - mean_squared_error: 0.1368 - mean_absolute_error: 0.2742 - mean_absolute_percentage_error: 4.3798 - cosine_proximity: -1.0000 - val_loss: 0.1362 - val_mean_squared_error: 0.1362 - val_mean_absolute_error: 0.2719 - val_mean_absolute_percentage_error: 4.3090 - val_cosine_proximity: -1.0000
# Epoch 8/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1353 - mean_squared_error: 0.1353 - mean_absolute_error: 0.2724 - mean_absolute_percentage_error: 4.3513 - cosine_proximity: -1.0000 - val_loss: 0.1357 - val_mean_squared_error: 0.1357 - val_mean_absolute_error: 0.2741 - val_mean_absolute_percentage_error: 4.4261 - val_cosine_proximity: -1.0000
# Epoch 9/100
# 925585/925585 [==============================] - 10s 11us/step - loss: 0.1342 - mean_squared_error: 0.1342 - mean_absolute_error: 0.2711 - mean_absolute_percentage_error: 4.3305 - cosine_proximity: -1.0000 - val_loss: 0.1393 - val_mean_squared_error: 0.1393 - val_mean_absolute_error: 0.2792 - val_mean_absolute_percentage_error: 4.5145 - val_cosine_proximity: -1.0000
# Epoch 10/100
# 925585/925585 [==============================] - 10s 10us/step - loss: 0.1337 - mean_squared_error: 0.1337 - mean_absolute_error: 0.2704 - mean_absolute_percentage_error: 4.3203 - cosine_proximity: -1.0000 - val_loss: 0.1334 - val_mean_squared_error: 0.1334 - val_mean_absolute_error: 0.2703 - val_mean_absolute_percentage_error: 4.3327 - val_cosine_proximity: -1.0000
# Epoch 11/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1330 - mean_squared_error: 0.1330 - mean_absolute_error: 0.2696 - mean_absolute_percentage_error: 4.3073 - cosine_proximity: -1.0000 - val_loss: 0.1317 - val_mean_squared_error: 0.1317 - val_mean_absolute_error: 0.2679 - val_mean_absolute_percentage_error: 4.2947 - val_cosine_proximity: -1.0000
# Epoch 12/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1324 - mean_squared_error: 0.1324 - mean_absolute_error: 0.2688 - mean_absolute_percentage_error: 4.2958 - cosine_proximity: -1.0000 - val_loss: 0.1308 - val_mean_squared_error: 0.1308 - val_mean_absolute_error: 0.2664 - val_mean_absolute_percentage_error: 4.2650 - val_cosine_proximity: -1.0000
# Epoch 13/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1318 - mean_squared_error: 0.1318 - mean_absolute_error: 0.2679 - mean_absolute_percentage_error: 4.2820 - cosine_proximity: -1.0000 - val_loss: 0.1320 - val_mean_squared_error: 0.1320 - val_mean_absolute_error: 0.2686 - val_mean_absolute_percentage_error: 4.3286 - val_cosine_proximity: -1.0000
# Epoch 14/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1311 - mean_squared_error: 0.1311 - mean_absolute_error: 0.2669 - mean_absolute_percentage_error: 4.2668 - cosine_proximity: -1.0000 - val_loss: 0.1344 - val_mean_squared_error: 0.1344 - val_mean_absolute_error: 0.2688 - val_mean_absolute_percentage_error: 4.2476 - val_cosine_proximity: -1.0000
# Epoch 15/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1307 - mean_squared_error: 0.1307 - mean_absolute_error: 0.2666 - mean_absolute_percentage_error: 4.2615 - cosine_proximity: -1.0000 - val_loss: 0.1306 - val_mean_squared_error: 0.1306 - val_mean_absolute_error: 0.2664 - val_mean_absolute_percentage_error: 4.2733 - val_cosine_proximity: -1.0000
# Epoch 16/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1303 - mean_squared_error: 0.1303 - mean_absolute_error: 0.2660 - mean_absolute_percentage_error: 4.2525 - cosine_proximity: -1.0000 - val_loss: 0.1287 - val_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.2633 - val_mean_absolute_percentage_error: 4.2050 - val_cosine_proximity: -1.0000
# Epoch 17/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1298 - mean_squared_error: 0.1298 - mean_absolute_error: 0.2654 - mean_absolute_percentage_error: 4.2431 - cosine_proximity: -1.0000 - val_loss: 0.1309 - val_mean_squared_error: 0.1309 - val_mean_absolute_error: 0.2650 - val_mean_absolute_percentage_error: 4.2016 - val_cosine_proximity: -1.0000
# Epoch 18/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1295 - mean_squared_error: 0.1295 - mean_absolute_error: 0.2649 - mean_absolute_percentage_error: 4.2359 - cosine_proximity: -1.0000 - val_loss: 0.1310 - val_mean_squared_error: 0.1310 - val_mean_absolute_error: 0.2671 - val_mean_absolute_percentage_error: 4.3030 - val_cosine_proximity: -1.0000
# Epoch 19/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1291 - mean_squared_error: 0.1291 - mean_absolute_error: 0.2645 - mean_absolute_percentage_error: 4.2292 - cosine_proximity: -1.0000 - val_loss: 0.1303 - val_mean_squared_error: 0.1303 - val_mean_absolute_error: 0.2651 - val_mean_absolute_percentage_error: 4.2105 - val_cosine_proximity: -1.0000
# Epoch 20/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1287 - mean_squared_error: 0.1287 - mean_absolute_error: 0.2639 - mean_absolute_percentage_error: 4.2201 - cosine_proximity: -1.0000 - val_loss: 0.1274 - val_mean_squared_error: 0.1274 - val_mean_absolute_error: 0.2613 - val_mean_absolute_percentage_error: 4.1659 - val_cosine_proximity: -1.0000
# Epoch 21/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1282 - mean_squared_error: 0.1282 - mean_absolute_error: 0.2634 - mean_absolute_percentage_error: 4.2117 - cosine_proximity: -1.0000 - val_loss: 0.1301 - val_mean_squared_error: 0.1301 - val_mean_absolute_error: 0.2641 - val_mean_absolute_percentage_error: 4.1910 - val_cosine_proximity: -1.0000
# Epoch 22/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1279 - mean_squared_error: 0.1279 - mean_absolute_error: 0.2628 - mean_absolute_percentage_error: 4.2035 - cosine_proximity: -1.0000 - val_loss: 0.1279 - val_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.2613 - val_mean_absolute_percentage_error: 4.1595 - val_cosine_proximity: -1.0000
# Epoch 23/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1274 - mean_squared_error: 0.1274 - mean_absolute_error: 0.2622 - mean_absolute_percentage_error: 4.1941 - cosine_proximity: -1.0000 - val_loss: 0.1264 - val_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.2602 - val_mean_absolute_percentage_error: 4.1561 - val_cosine_proximity: -1.0000
# Epoch 24/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1270 - mean_squared_error: 0.1270 - mean_absolute_error: 0.2618 - mean_absolute_percentage_error: 4.1876 - cosine_proximity: -1.0000 - val_loss: 0.1283 - val_mean_squared_error: 0.1283 - val_mean_absolute_error: 0.2617 - val_mean_absolute_percentage_error: 4.1474 - val_cosine_proximity: -1.0000
# Epoch 25/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1266 - mean_squared_error: 0.1266 - mean_absolute_error: 0.2614 - mean_absolute_percentage_error: 4.1808 - cosine_proximity: -1.0000 - val_loss: 0.1263 - val_mean_squared_error: 0.1263 - val_mean_absolute_error: 0.2602 - val_mean_absolute_percentage_error: 4.1461 - val_cosine_proximity: -1.0000
# Epoch 26/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1262 - mean_squared_error: 0.1262 - mean_absolute_error: 0.2609 - mean_absolute_percentage_error: 4.1728 - cosine_proximity: -1.0000 - val_loss: 0.1276 - val_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.2626 - val_mean_absolute_percentage_error: 4.2240 - val_cosine_proximity: -1.0000
# Epoch 27/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1256 - mean_squared_error: 0.1256 - mean_absolute_error: 0.2601 - mean_absolute_percentage_error: 4.1605 - cosine_proximity: -1.0000 - val_loss: 0.1253 - val_mean_squared_error: 0.1253 - val_mean_absolute_error: 0.2592 - val_mean_absolute_percentage_error: 4.1505 - val_cosine_proximity: -1.0000
# Epoch 28/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1254 - mean_squared_error: 0.1254 - mean_absolute_error: 0.2599 - mean_absolute_percentage_error: 4.1580 - cosine_proximity: -1.0000 - val_loss: 0.1247 - val_mean_squared_error: 0.1247 - val_mean_absolute_error: 0.2581 - val_mean_absolute_percentage_error: 4.1234 - val_cosine_proximity: -1.0000
# Epoch 29/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1252 - mean_squared_error: 0.1252 - mean_absolute_error: 0.2596 - mean_absolute_percentage_error: 4.1526 - cosine_proximity: -1.0000 - val_loss: 0.1285 - val_mean_squared_error: 0.1285 - val_mean_absolute_error: 0.2622 - val_mean_absolute_percentage_error: 4.1480 - val_cosine_proximity: -1.0000
# Epoch 30/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1248 - mean_squared_error: 0.1248 - mean_absolute_error: 0.2591 - mean_absolute_percentage_error: 4.1446 - cosine_proximity: -1.0000 - val_loss: 0.1241 - val_mean_squared_error: 0.1241 - val_mean_absolute_error: 0.2585 - val_mean_absolute_percentage_error: 4.1490 - val_cosine_proximity: -1.0000
# Epoch 31/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1246 - mean_squared_error: 0.1246 - mean_absolute_error: 0.2589 - mean_absolute_percentage_error: 4.1411 - cosine_proximity: -1.0000 - val_loss: 0.1254 - val_mean_squared_error: 0.1254 - val_mean_absolute_error: 0.2586 - val_mean_absolute_percentage_error: 4.1195 - val_cosine_proximity: -1.0000
# Epoch 32/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1243 - mean_squared_error: 0.1243 - mean_absolute_error: 0.2585 - mean_absolute_percentage_error: 4.1353 - cosine_proximity: -1.0000 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.2562 - val_mean_absolute_percentage_error: 4.1051 - val_cosine_proximity: -1.0000
# Epoch 33/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1240 - mean_squared_error: 0.1240 - mean_absolute_error: 0.2581 - mean_absolute_percentage_error: 4.1288 - cosine_proximity: -1.0000 - val_loss: 0.1233 - val_mean_squared_error: 0.1233 - val_mean_absolute_error: 0.2566 - val_mean_absolute_percentage_error: 4.1041 - val_cosine_proximity: -1.0000
# Epoch 34/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1238 - mean_squared_error: 0.1238 - mean_absolute_error: 0.2579 - mean_absolute_percentage_error: 4.1258 - cosine_proximity: -1.0000 - val_loss: 0.1243 - val_mean_squared_error: 0.1243 - val_mean_absolute_error: 0.2582 - val_mean_absolute_percentage_error: 4.1347 - val_cosine_proximity: -1.0000
# Epoch 35/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1235 - mean_squared_error: 0.1235 - mean_absolute_error: 0.2576 - mean_absolute_percentage_error: 4.1203 - cosine_proximity: -1.0000 - val_loss: 0.1240 - val_mean_squared_error: 0.1240 - val_mean_absolute_error: 0.2574 - val_mean_absolute_percentage_error: 4.1162 - val_cosine_proximity: -1.0000
# Epoch 36/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1233 - mean_squared_error: 0.1233 - mean_absolute_error: 0.2572 - mean_absolute_percentage_error: 4.1145 - cosine_proximity: -1.0000 - val_loss: 0.1230 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.2560 - val_mean_absolute_percentage_error: 4.0935 - val_cosine_proximity: -1.0000
# Epoch 37/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1230 - mean_squared_error: 0.1230 - mean_absolute_error: 0.2568 - mean_absolute_percentage_error: 4.1088 - cosine_proximity: -1.0000 - val_loss: 0.1222 - val_mean_squared_error: 0.1222 - val_mean_absolute_error: 0.2549 - val_mean_absolute_percentage_error: 4.0749 - val_cosine_proximity: -1.0000
# Epoch 38/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1229 - mean_squared_error: 0.1229 - mean_absolute_error: 0.2568 - mean_absolute_percentage_error: 4.1082 - cosine_proximity: -1.0000 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_mean_absolute_error: 0.2549 - val_mean_absolute_percentage_error: 4.0762 - val_cosine_proximity: -1.0000
# Epoch 39/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1229 - mean_squared_error: 0.1229 - mean_absolute_error: 0.2567 - mean_absolute_percentage_error: 4.1067 - cosine_proximity: -1.0000 - val_loss: 0.1218 - val_mean_squared_error: 0.1218 - val_mean_absolute_error: 0.2546 - val_mean_absolute_percentage_error: 4.0741 - val_cosine_proximity: -1.0000
# Epoch 40/100
# 925585/925585 [==============================] - 10s 11us/step - loss: 0.1226 - mean_squared_error: 0.1226 - mean_absolute_error: 0.2564 - mean_absolute_percentage_error: 4.1021 - cosine_proximity: -1.0000 - val_loss: 0.1265 - val_mean_squared_error: 0.1265 - val_mean_absolute_error: 0.2615 - val_mean_absolute_percentage_error: 4.2306 - val_cosine_proximity: -1.0000
# Epoch 41/100
# 925585/925585 [==============================] - 10s 10us/step - loss: 0.1225 - mean_squared_error: 0.1225 - mean_absolute_error: 0.2564 - mean_absolute_percentage_error: 4.1018 - cosine_proximity: -1.0000 - val_loss: 0.1225 - val_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.2549 - val_mean_absolute_percentage_error: 4.0656 - val_cosine_proximity: -1.0000
# Epoch 42/100
# 925585/925585 [==============================] - 10s 10us/step - loss: 0.1224 - mean_squared_error: 0.1224 - mean_absolute_error: 0.2561 - mean_absolute_percentage_error: 4.0981 - cosine_proximity: -1.0000 - val_loss: 0.1235 - val_mean_squared_error: 0.1235 - val_mean_absolute_error: 0.2575 - val_mean_absolute_percentage_error: 4.1501 - val_cosine_proximity: -1.0000
# Epoch 43/100
# 925585/925585 [==============================] - 10s 11us/step - loss: 0.1223 - mean_squared_error: 0.1223 - mean_absolute_error: 0.2560 - mean_absolute_percentage_error: 4.0952 - cosine_proximity: -1.0000 - val_loss: 0.1335 - val_mean_squared_error: 0.1335 - val_mean_absolute_error: 0.2724 - val_mean_absolute_percentage_error: 4.4215 - val_cosine_proximity: -1.0000
# Epoch 44/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1221 - mean_squared_error: 0.1221 - mean_absolute_error: 0.2558 - mean_absolute_percentage_error: 4.0920 - cosine_proximity: -1.0000 - val_loss: 0.1242 - val_mean_squared_error: 0.1242 - val_mean_absolute_error: 0.2588 - val_mean_absolute_percentage_error: 4.1806 - val_cosine_proximity: -1.0000
# Epoch 45/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1221 - mean_squared_error: 0.1221 - mean_absolute_error: 0.2557 - mean_absolute_percentage_error: 4.0914 - cosine_proximity: -1.0000 - val_loss: 0.1236 - val_mean_squared_error: 0.1236 - val_mean_absolute_error: 0.2555 - val_mean_absolute_percentage_error: 4.0539 - val_cosine_proximity: -1.0000
# Epoch 46/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1219 - mean_squared_error: 0.1219 - mean_absolute_error: 0.2556 - mean_absolute_percentage_error: 4.0889 - cosine_proximity: -1.0000 - val_loss: 0.1225 - val_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.2562 - val_mean_absolute_percentage_error: 4.1127 - val_cosine_proximity: -1.0000
# Epoch 47/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1219 - mean_squared_error: 0.1219 - mean_absolute_error: 0.2555 - mean_absolute_percentage_error: 4.0882 - cosine_proximity: -1.0000 - val_loss: 0.1252 - val_mean_squared_error: 0.1252 - val_mean_absolute_error: 0.2587 - val_mean_absolute_percentage_error: 4.0971 - val_cosine_proximity: -1.0000
# Epoch 48/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1217 - mean_squared_error: 0.1217 - mean_absolute_error: 0.2552 - mean_absolute_percentage_error: 4.0833 - cosine_proximity: -1.0000 - val_loss: 0.1228 - val_mean_squared_error: 0.1228 - val_mean_absolute_error: 0.2553 - val_mean_absolute_percentage_error: 4.0747 - val_cosine_proximity: -1.0000
# Epoch 49/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1217 - mean_squared_error: 0.1217 - mean_absolute_error: 0.2553 - mean_absolute_percentage_error: 4.0842 - cosine_proximity: -1.0000 - val_loss: 0.1220 - val_mean_squared_error: 0.1220 - val_mean_absolute_error: 0.2554 - val_mean_absolute_percentage_error: 4.0968 - val_cosine_proximity: -1.0000
# Epoch 50/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1217 - mean_squared_error: 0.1217 - mean_absolute_error: 0.2552 - mean_absolute_percentage_error: 4.0839 - cosine_proximity: -1.0000 - val_loss: 0.1215 - val_mean_squared_error: 0.1215 - val_mean_absolute_error: 0.2543 - val_mean_absolute_percentage_error: 4.0673 - val_cosine_proximity: -1.0000
# Epoch 51/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1215 - mean_squared_error: 0.1215 - mean_absolute_error: 0.2550 - mean_absolute_percentage_error: 4.0799 - cosine_proximity: -1.0000 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_mean_absolute_error: 0.2535 - val_mean_absolute_percentage_error: 4.0575 - val_cosine_proximity: -1.0000
# Epoch 52/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1214 - mean_squared_error: 0.1214 - mean_absolute_error: 0.2550 - mean_absolute_percentage_error: 4.0804 - cosine_proximity: -1.0000 - val_loss: 0.1213 - val_mean_squared_error: 0.1213 - val_mean_absolute_error: 0.2543 - val_mean_absolute_percentage_error: 4.0817 - val_cosine_proximity: -1.0000
# Epoch 53/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1214 - mean_squared_error: 0.1214 - mean_absolute_error: 0.2549 - mean_absolute_percentage_error: 4.0783 - cosine_proximity: -1.0000 - val_loss: 0.1212 - val_mean_squared_error: 0.1212 - val_mean_absolute_error: 0.2537 - val_mean_absolute_percentage_error: 4.0582 - val_cosine_proximity: -1.0000
# Epoch 54/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1213 - mean_squared_error: 0.1213 - mean_absolute_error: 0.2547 - mean_absolute_percentage_error: 4.0757 - cosine_proximity: -1.0000 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_mean_absolute_error: 0.2537 - val_mean_absolute_percentage_error: 4.0663 - val_cosine_proximity: -1.0000
# Epoch 55/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1211 - mean_squared_error: 0.1211 - mean_absolute_error: 0.2545 - mean_absolute_percentage_error: 4.0726 - cosine_proximity: -1.0000 - val_loss: 0.1211 - val_mean_squared_error: 0.1211 - val_mean_absolute_error: 0.2536 - val_mean_absolute_percentage_error: 4.0636 - val_cosine_proximity: -1.0000
# Epoch 56/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1211 - mean_squared_error: 0.1211 - mean_absolute_error: 0.2546 - mean_absolute_percentage_error: 4.0730 - cosine_proximity: -1.0000 - val_loss: 0.1217 - val_mean_squared_error: 0.1217 - val_mean_absolute_error: 0.2551 - val_mean_absolute_percentage_error: 4.0890 - val_cosine_proximity: -1.0000
# Epoch 57/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1211 - mean_squared_error: 0.1211 - mean_absolute_error: 0.2545 - mean_absolute_percentage_error: 4.0729 - cosine_proximity: -1.0000 - val_loss: 0.1223 - val_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.2560 - val_mean_absolute_percentage_error: 4.1271 - val_cosine_proximity: -1.0000
# Epoch 58/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1209 - mean_squared_error: 0.1209 - mean_absolute_error: 0.2544 - mean_absolute_percentage_error: 4.0708 - cosine_proximity: -1.0000 - val_loss: 0.1245 - val_mean_squared_error: 0.1245 - val_mean_absolute_error: 0.2602 - val_mean_absolute_percentage_error: 4.2004 - val_cosine_proximity: -1.0000
# Epoch 59/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1208 - mean_squared_error: 0.1208 - mean_absolute_error: 0.2542 - mean_absolute_percentage_error: 4.0672 - cosine_proximity: -1.0000 - val_loss: 0.1206 - val_mean_squared_error: 0.1206 - val_mean_absolute_error: 0.2531 - val_mean_absolute_percentage_error: 4.0509 - val_cosine_proximity: -1.0000
# Epoch 60/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1207 - mean_squared_error: 0.1207 - mean_absolute_error: 0.2541 - mean_absolute_percentage_error: 4.0664 - cosine_proximity: -1.0000 - val_loss: 0.1232 - val_mean_squared_error: 0.1232 - val_mean_absolute_error: 0.2565 - val_mean_absolute_percentage_error: 4.0851 - val_cosine_proximity: -1.0000
# Epoch 61/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1206 - mean_squared_error: 0.1206 - mean_absolute_error: 0.2541 - mean_absolute_percentage_error: 4.0648 - cosine_proximity: -1.0000 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_mean_absolute_error: 0.2524 - val_mean_absolute_percentage_error: 4.0467 - val_cosine_proximity: -1.0000
# Epoch 62/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1205 - mean_squared_error: 0.1205 - mean_absolute_error: 0.2539 - mean_absolute_percentage_error: 4.0623 - cosine_proximity: -1.0000 - val_loss: 0.1203 - val_mean_squared_error: 0.1203 - val_mean_absolute_error: 0.2526 - val_mean_absolute_percentage_error: 4.0467 - val_cosine_proximity: -1.0000
# Epoch 63/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1204 - mean_squared_error: 0.1204 - mean_absolute_error: 0.2538 - mean_absolute_percentage_error: 4.0614 - cosine_proximity: -1.0000 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - val_mean_absolute_error: 0.2542 - val_mean_absolute_percentage_error: 4.0881 - val_cosine_proximity: -1.0000
# Epoch 64/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1203 - mean_squared_error: 0.1203 - mean_absolute_error: 0.2536 - mean_absolute_percentage_error: 4.0583 - cosine_proximity: -1.0000 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - val_mean_absolute_error: 0.2529 - val_mean_absolute_percentage_error: 4.0403 - val_cosine_proximity: -1.0000
# Epoch 65/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1203 - mean_squared_error: 0.1203 - mean_absolute_error: 0.2536 - mean_absolute_percentage_error: 4.0587 - cosine_proximity: -1.0000 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.2525 - val_mean_absolute_percentage_error: 4.0446 - val_cosine_proximity: -1.0000
# Epoch 66/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1203 - mean_squared_error: 0.1203 - mean_absolute_error: 0.2536 - mean_absolute_percentage_error: 4.0576 - cosine_proximity: -1.0000 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_mean_absolute_error: 0.2530 - val_mean_absolute_percentage_error: 4.0394 - val_cosine_proximity: -1.0000
# Epoch 67/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1201 - mean_squared_error: 0.1201 - mean_absolute_error: 0.2533 - mean_absolute_percentage_error: 4.0535 - cosine_proximity: -1.0000 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_mean_absolute_error: 0.2529 - val_mean_absolute_percentage_error: 4.0579 - val_cosine_proximity: -1.0000
# Epoch 68/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1200 - mean_squared_error: 0.1200 - mean_absolute_error: 0.2532 - mean_absolute_percentage_error: 4.0519 - cosine_proximity: -1.0000 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - val_mean_absolute_error: 0.2527 - val_mean_absolute_percentage_error: 4.0413 - val_cosine_proximity: -1.0000
# Epoch 69/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1199 - mean_squared_error: 0.1199 - mean_absolute_error: 0.2531 - mean_absolute_percentage_error: 4.0502 - cosine_proximity: -1.0000 - val_loss: 0.1238 - val_mean_squared_error: 0.1238 - val_mean_absolute_error: 0.2585 - val_mean_absolute_percentage_error: 4.1768 - val_cosine_proximity: -1.0000
# Epoch 70/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1199 - mean_squared_error: 0.1199 - mean_absolute_error: 0.2531 - mean_absolute_percentage_error: 4.0500 - cosine_proximity: -1.0000 - val_loss: 0.1224 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.2568 - val_mean_absolute_percentage_error: 4.1296 - val_cosine_proximity: -1.0000
# Epoch 71/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1198 - mean_squared_error: 0.1198 - mean_absolute_error: 0.2531 - mean_absolute_percentage_error: 4.0501 - cosine_proximity: -1.0000 - val_loss: 0.1195 - val_mean_squared_error: 0.1195 - val_mean_absolute_error: 0.2514 - val_mean_absolute_percentage_error: 4.0230 - val_cosine_proximity: -1.0000
# Epoch 72/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1197 - mean_squared_error: 0.1197 - mean_absolute_error: 0.2530 - mean_absolute_percentage_error: 4.0482 - cosine_proximity: -1.0000 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_mean_absolute_error: 0.2512 - val_mean_absolute_percentage_error: 4.0125 - val_cosine_proximity: -1.0000
# Epoch 73/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1197 - mean_squared_error: 0.1197 - mean_absolute_error: 0.2529 - mean_absolute_percentage_error: 4.0464 - cosine_proximity: -1.0000 - val_loss: 0.1197 - val_mean_squared_error: 0.1197 - val_mean_absolute_error: 0.2519 - val_mean_absolute_percentage_error: 4.0399 - val_cosine_proximity: -1.0000
# Epoch 74/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1197 - mean_squared_error: 0.1197 - mean_absolute_error: 0.2529 - mean_absolute_percentage_error: 4.0458 - cosine_proximity: -1.0000 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.2522 - val_mean_absolute_percentage_error: 4.0427 - val_cosine_proximity: -1.0000
# Epoch 75/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1195 - mean_squared_error: 0.1195 - mean_absolute_error: 0.2527 - mean_absolute_percentage_error: 4.0433 - cosine_proximity: -1.0000 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_mean_absolute_error: 0.2543 - val_mean_absolute_percentage_error: 4.0973 - val_cosine_proximity: -1.0000
# Epoch 76/100
# 925585/925585 [==============================] - 10s 10us/step - loss: 0.1194 - mean_squared_error: 0.1194 - mean_absolute_error: 0.2525 - mean_absolute_percentage_error: 4.0404 - cosine_proximity: -1.0000 - val_loss: 0.1198 - val_mean_squared_error: 0.1198 - val_mean_absolute_error: 0.2513 - val_mean_absolute_percentage_error: 4.0055 - val_cosine_proximity: -1.0000
# Epoch 77/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1194 - mean_squared_error: 0.1194 - mean_absolute_error: 0.2525 - mean_absolute_percentage_error: 4.0394 - cosine_proximity: -1.0000 - val_loss: 0.1203 - val_mean_squared_error: 0.1203 - val_mean_absolute_error: 0.2523 - val_mean_absolute_percentage_error: 4.0287 - val_cosine_proximity: -1.0000
# Epoch 78/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1192 - mean_squared_error: 0.1192 - mean_absolute_error: 0.2523 - mean_absolute_percentage_error: 4.0374 - cosine_proximity: -1.0000 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.2518 - val_mean_absolute_percentage_error: 4.0196 - val_cosine_proximity: -1.0000
# Epoch 79/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1193 - mean_squared_error: 0.1193 - mean_absolute_error: 0.2525 - mean_absolute_percentage_error: 4.0406 - cosine_proximity: -1.0000 - val_loss: 0.1199 - val_mean_squared_error: 0.1199 - val_mean_absolute_error: 0.2528 - val_mean_absolute_percentage_error: 4.0508 - val_cosine_proximity: -1.0000
# Epoch 80/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1192 - mean_squared_error: 0.1192 - mean_absolute_error: 0.2522 - mean_absolute_percentage_error: 4.0357 - cosine_proximity: -1.0000 - val_loss: 0.1218 - val_mean_squared_error: 0.1218 - val_mean_absolute_error: 0.2560 - val_mean_absolute_percentage_error: 4.1300 - val_cosine_proximity: -1.0000
# Epoch 81/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1191 - mean_squared_error: 0.1191 - mean_absolute_error: 0.2522 - mean_absolute_percentage_error: 4.0355 - cosine_proximity: -1.0000 - val_loss: 0.1193 - val_mean_squared_error: 0.1193 - val_mean_absolute_error: 0.2516 - val_mean_absolute_percentage_error: 4.0341 - val_cosine_proximity: -1.0000
# Epoch 82/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1190 - mean_squared_error: 0.1190 - mean_absolute_error: 0.2521 - mean_absolute_percentage_error: 4.0329 - cosine_proximity: -1.0000 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_mean_absolute_error: 0.2513 - val_mean_absolute_percentage_error: 4.0149 - val_cosine_proximity: -1.0000
# Epoch 83/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1188 - mean_squared_error: 0.1188 - mean_absolute_error: 0.2519 - mean_absolute_percentage_error: 4.0296 - cosine_proximity: -1.0000 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - val_mean_absolute_error: 0.2541 - val_mean_absolute_percentage_error: 4.0746 - val_cosine_proximity: -1.0000
# Epoch 84/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1188 - mean_squared_error: 0.1188 - mean_absolute_error: 0.2519 - mean_absolute_percentage_error: 4.0298 - cosine_proximity: -1.0000 - val_loss: 0.1232 - val_mean_squared_error: 0.1232 - val_mean_absolute_error: 0.2582 - val_mean_absolute_percentage_error: 4.1706 - val_cosine_proximity: -1.0000
# Epoch 85/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1188 - mean_squared_error: 0.1188 - mean_absolute_error: 0.2518 - mean_absolute_percentage_error: 4.0288 - cosine_proximity: -1.0000 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_mean_absolute_error: 0.2512 - val_mean_absolute_percentage_error: 4.0259 - val_cosine_proximity: -1.0000
# Epoch 86/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1188 - mean_squared_error: 0.1188 - mean_absolute_error: 0.2518 - mean_absolute_percentage_error: 4.0287 - cosine_proximity: -1.0000 - val_loss: 0.1197 - val_mean_squared_error: 0.1197 - val_mean_absolute_error: 0.2518 - val_mean_absolute_percentage_error: 4.0281 - val_cosine_proximity: -1.0000
# Epoch 87/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1186 - mean_squared_error: 0.1186 - mean_absolute_error: 0.2516 - mean_absolute_percentage_error: 4.0259 - cosine_proximity: -1.0000 - val_loss: 0.1197 - val_mean_squared_error: 0.1197 - val_mean_absolute_error: 0.2519 - val_mean_absolute_percentage_error: 4.0374 - val_cosine_proximity: -1.0000
# Epoch 88/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1186 - mean_squared_error: 0.1186 - mean_absolute_error: 0.2515 - mean_absolute_percentage_error: 4.0246 - cosine_proximity: -1.0000 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - val_mean_absolute_error: 0.2513 - val_mean_absolute_percentage_error: 4.0357 - val_cosine_proximity: -1.0000
# Epoch 89/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1186 - mean_squared_error: 0.1186 - mean_absolute_error: 0.2516 - mean_absolute_percentage_error: 4.0252 - cosine_proximity: -1.0000 - val_loss: 0.1191 - val_mean_squared_error: 0.1191 - val_mean_absolute_error: 0.2507 - val_mean_absolute_percentage_error: 4.0022 - val_cosine_proximity: -1.0000
# Epoch 90/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1184 - mean_squared_error: 0.1184 - mean_absolute_error: 0.2513 - mean_absolute_percentage_error: 4.0205 - cosine_proximity: -1.0000 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_mean_absolute_error: 0.2530 - val_mean_absolute_percentage_error: 4.0690 - val_cosine_proximity: -1.0000
# Epoch 91/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1185 - mean_squared_error: 0.1185 - mean_absolute_error: 0.2514 - mean_absolute_percentage_error: 4.0219 - cosine_proximity: -1.0000 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_mean_absolute_error: 0.2518 - val_mean_absolute_percentage_error: 4.0067 - val_cosine_proximity: -1.0000
# Epoch 92/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1185 - mean_squared_error: 0.1185 - mean_absolute_error: 0.2514 - mean_absolute_percentage_error: 4.0230 - cosine_proximity: -1.0000 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_mean_absolute_error: 0.2527 - val_mean_absolute_percentage_error: 4.0390 - val_cosine_proximity: -1.0000
# Epoch 93/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1184 - mean_squared_error: 0.1184 - mean_absolute_error: 0.2513 - mean_absolute_percentage_error: 4.0201 - cosine_proximity: -1.0000 - val_loss: 0.1194 - val_mean_squared_error: 0.1194 - val_mean_absolute_error: 0.2511 - val_mean_absolute_percentage_error: 4.0152 - val_cosine_proximity: -1.0000
# Epoch 94/100
# 925585/925585 [==============================] - 9s 9us/step - loss: 0.1183 - mean_squared_error: 0.1183 - mean_absolute_error: 0.2511 - mean_absolute_percentage_error: 4.0179 - cosine_proximity: -1.0000 - val_loss: 0.1185 - val_mean_squared_error: 0.1185 - val_mean_absolute_error: 0.2501 - val_mean_absolute_percentage_error: 3.9901 - val_cosine_proximity: -1.0000
# Epoch 95/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1183 - mean_squared_error: 0.1183 - mean_absolute_error: 0.2512 - mean_absolute_percentage_error: 4.0195 - cosine_proximity: -1.0000 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - val_mean_absolute_error: 0.2525 - val_mean_absolute_percentage_error: 4.0315 - val_cosine_proximity: -1.0000
# Epoch 96/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1183 - mean_squared_error: 0.1183 - mean_absolute_error: 0.2512 - mean_absolute_percentage_error: 4.0189 - cosine_proximity: -1.0000 - val_loss: 0.1208 - val_mean_squared_error: 0.1208 - val_mean_absolute_error: 0.2527 - val_mean_absolute_percentage_error: 4.0261 - val_cosine_proximity: -1.0000
# Epoch 97/100
# 925585/925585 [==============================] - 9s 9us/step - loss: 0.1182 - mean_squared_error: 0.1182 - mean_absolute_error: 0.2511 - mean_absolute_percentage_error: 4.0174 - cosine_proximity: -1.0000 - val_loss: 0.1201 - val_mean_squared_error: 0.1201 - val_mean_absolute_error: 0.2519 - val_mean_absolute_percentage_error: 4.0089 - val_cosine_proximity: -1.0000
# Epoch 98/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1181 - mean_squared_error: 0.1181 - mean_absolute_error: 0.2510 - mean_absolute_percentage_error: 4.0162 - cosine_proximity: -1.0000 - val_loss: 0.1185 - val_mean_squared_error: 0.1185 - val_mean_absolute_error: 0.2507 - val_mean_absolute_percentage_error: 4.0239 - val_cosine_proximity: -1.0000
# Epoch 99/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1180 - mean_squared_error: 0.1180 - mean_absolute_error: 0.2509 - mean_absolute_percentage_error: 4.0135 - cosine_proximity: -1.0000 - val_loss: 0.1188 - val_mean_squared_error: 0.1188 - val_mean_absolute_error: 0.2507 - val_mean_absolute_percentage_error: 4.0224 - val_cosine_proximity: -1.0000
# Epoch 100/100
# 925585/925585 [==============================] - 9s 10us/step - loss: 0.1181 - mean_squared_error: 0.1181 - mean_absolute_error: 0.2508 - mean_absolute_percentage_error: 4.0132 - cosine_proximity: -1.0000 - val_loss: 0.1184 - val_mean_squared_error: 0.1184 - val_mean_absolute_error: 0.2504 - val_mean_absolute_percentage_error: 4.0186 - val_cosine_proximity: -1.0000

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#     val_loss  val_mean_squared_error  ...  cosine_proximity  epoch
# 95  0.120779                0.120779  ...              -1.0     95
# 96  0.120137                0.120137  ...              -1.0     96
# 97  0.118503                0.118503  ...              -1.0     97
# 98  0.118778                0.118778  ...              -1.0     98
# 99  0.118415                0.118415  ...              -1.0     99
#
# [5 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
n_epochs = 100
x_plot = list(range(1,n_epochs+1))

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(x_plot, network_history.history['loss'])
    plt.plot(x_plot, network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('cosine_proximity')
    plt.plot(x_plot, network_history.history['cosine_proximity'])
    plt.plot(x_plot, network_history.history['val_cosine_proximity'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('mean_absolute_error')
    plt.plot(x_plot, network_history.history['mean_absolute_error'])
    plt.plot(x_plot, network_history.history['val_mean_absolute_error'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('mean_absolute_percentage_error')
    plt.plot(x_plot, network_history.history['mean_absolute_percentage_error'])
    plt.plot(x_plot, network_history.history['val_mean_absolute_percentage_error'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('mean_squared_error')
    plt.plot(x_plot, network_history.history['mean_squared_error'])
    plt.plot(x_plot, network_history.history['val_mean_squared_error'])
    plt.legend(['Training', 'Validation'])

plot_history(history)

# %%
import tensorflow as tf
# !pip install git+https://github.com/tensorflow/docs
print(tf.__version__)
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mean_absolute_error")
plt.ylim([0, 10])
plt.ylabel('MAE [MPG]')

# %%
from matplotlib import pyplot

# plot metrics
pyplot.plot(history.history['mean_squared_error'])
pyplot.plot(history.history['mean_absolute_error'])
pyplot.plot(history.history['mean_absolute_percentage_error'])
pyplot.plot(history.history['cosine_proximity'])
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-0b786dc0ec15> in <module>()
#       2
#       3 # plot metrics
# ----> 4 pyplot.plot(history.history['mean_squared_error'])
#       5 pyplot.plot(history.history['mean_absolute_error'])
#       6 pyplot.plot(history.history['mean_absolute_percentage_error'])
#
# KeyError: 'mean_squared_error'

# %%
pred = model.predict(test_scaled_x)
pred = pred.flatten()
pred = np.exp(pred)+1

# %%
import matplotlib.pyplot as plt

a = plt.axes(aspect='equal')
plt.scatter(test_y, pred)
plt.xlabel('True Values [trip_duration]')
plt.ylabel('Predictions [trip_duration]')
lims = [0, 18000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# Root Mean Squared Logarithmic Error
np.sqrt(np.mean(np.square(np.log(pred + 1) - np.log(test_y + 1)), axis=-1))
# Out:
# 0.34389327645000733

# %% [markdown]
# # Prediction

# %%
# carlo
#test_weather_osm = pd.read_csv("/content/drive/My Drive/universita/magistrale/advanced_machine_learning/Progetto AML/test_weather_osm_50_clusters.csv")
# pietro
test_weather_osm = pd.read_csv("/content/drive/My Drive/UnimiB/Magistrale/Secondo Anno/Advanced Machine Learning/Progetto AML/test_weather_osm_50_clusters.csv")

test_weather_osm = test_weather_osm.drop(columns=['id'])

# %%
test_weather_osm.head()
# Out:
#    total_distance  total_travel_time  ...  pickup_minute  pickup_day_week
# 0          1497.1              200.2  ...              2                5
# 1          1427.1              141.5  ...             45                4
# 2          2312.3              324.6  ...             48                3
# 3           931.8               84.2  ...             20                4
# 4          2501.7              294.7  ...             37                4
#
# [5 rows x 21 columns]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

test_weather_osm_array = np.array(test_weather_osm)

test_weather_osm_scaled_x = scaler.transform(test_weather_osm_array)

# %%
pred = model.predict(test_weather_osm_scaled_x)
pred = pred.flatten()
pred = np.exp(pred)+1

# %%
# Carlo
# test_weather_osm = pd.read_csv("/content/drive/My Drive/universita/magistrale/advanced_machine_learning/Progetto AML/test_weather_osm_50_clusters.csv")
# Pietro
test_weather_osm = pd.read_csv("/content/drive/My Drive/UnimiB/Magistrale/Secondo Anno/Advanced Machine Learning/Progetto AML/test_weather_osm_50_clusters.csv")

test_weather_osm['trip_duration'] = pred.tolist()

test_weather_osm[['id', 'trip_duration']].to_csv('neural_submission_50_clusters.csv', index=False)
# pietro
# !cp /content/neural_submission_50_clusters.csv "/content/drive/My Drive/UnimiB/Magistrale/Secondo Anno/Advanced Machine Learning/Progetto AML/"
# carlo
#!cp /content/neural_submission_50_clusters.csv "/content/drive/My Drive/universita/magistrale/advanced_machine_learning/Progetto AML/"

# %%
test_weather_osm.shape
# Out:
# (625134, 23)
